# %% [markdown]
# # Problem 1

# %%
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt

# %%
pleiades = Table.read('C:/Users/dougl/Desktop/pleiades.csv', format = 'csv')

ngc188 = Table.read('C:/Users/dougl/Desktop/ngc188.csv', format = 'csv')

# %%
print(pleiades[1].columns)
# Out:
# <TableColumns names=('source_id','ra','ra_error','dec','dec_error','parallax','parallax_error','pmra','pmra_error','pmdec','pmdec_error','phot_g_mean_mag','bp_rp','radial_velocity','radial_velocity_error','phot_variable_flag','teff_val','a_g_val')>

# %%
print(ngc188[1].columns)
# Out:
# <TableColumns names=('source_id','ra','ra_error','dec','dec_error','parallax','parallax_error','pmra','pmra_error','pmdec','pmdec_error','phot_g_mean_mag','bp_rp','radial_velocity','radial_velocity_error','phot_variable_flag','teff_val','a_g_val')>

# %%
pl_gmag = pleiades["phot_g_mean_mag"]
pl_bprp = pleiades["bp_rp"]
pl_ext = pleiades["a_g_val"]
pl_pmra,pl_pmdec = pleiades["pmra"], pleiades["pmdec"]
pl_ra, pl_dec = pleiades["ra"], pleiades["dec"]

ngc_gmag = ngc188["phot_g_mean_mag"]
ngc_bprp = ngc188["bp_rp"]
ngc_ext = ngc188["a_g_val"]
ngc_pmra,ngc_pmdec = ngc188["pmra"], ngc188["pmdec"]
ngc_ra, ngc_dec = ngc188["ra"], ngc188["dec"]

# %% [markdown]
# # Pleiades

# %%
plt.scatter(pl_pmra,pl_pmdec, s=0.1)
plt.xlim(-50,50)
plt.ylim(-60,60)
plt.xlabel('$\mu_{a}$ [mas/yr]', fontsize=15)
plt.ylabel('$\mu_{\delta}$ [mas/yr]', fontsize=15)
# Out:
# Text(0,0.5,'$\\mu_{\\delta}$ [mas/yr]')

# %%
pl_d = 1000/(pleiades["parallax"])

pl_absgmag = pl_gmag - 5*np.log10(pl_d) + 5 + pl_ext

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,8))
ax[0].scatter(pl_bprp, pl_absgmag, s=.9, color='#666666')
ax[0].set_xlabel('BP-RP', fontsize=15)
ax[0].set_ylabel('Abs(G mag)', fontsize=15)
ax[0].set_ylim(ax[0].set_ylim(15,0)[::-1])
ax[0].set_title('Pleiades (1)', size=20)


ichoose1 = np.where((pl_pmra>18) & (pl_pmra<22) & (pl_pmdec>-58) & (pl_pmdec<-39) 
               & (pleiades['parallax'] > 5.5) & (pleiades['parallax'] < 8))

ax[1].scatter(pl_bprp, pl_absgmag, s=.4, color='#666666', alpha=0.5)
ax[1].scatter(pl_bprp[ichoose1], pl_absgmag[ichoose1], s=3, color='red', marker='o')


ax[1].set_xlabel('BP-RP', fontsize=15)
ax[1].set_ylabel('Abs(G mag)', fontsize=15)
ax[1].set_ylim(ax[1].set_ylim(15,0)[::-1])

#plt.savefig('cmd_ple.png', type='png')
# Out:
# C:\Users\dougl\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until
# (0, 15)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,8))
ax[0].scatter(pl_bprp, pl_gmag, s=.9, color='#666666')
ax[0].set_xlabel('BP-RP', fontsize=15)
ax[0].set_ylabel('G mag', fontsize=15)
ax[0].set_ylim(ax[0].set_ylim(6,21)[::-1])
ax[0].set_title('Pleiades (2)', size=16)


ichoose2 = np.where((pl_pmra>18) & (pl_pmra<22) & (pl_pmdec>-58) & (pl_pmdec<-39) 
               & (pleiades['parallax'] > 5.5) & (pleiades['parallax'] < 8))

ax[1].scatter(pl_bprp, pl_gmag, s=.4, color='#666666', alpha=0.5)
ax[1].scatter(pl_bprp[ichoose2], pl_gmag[ichoose2], s=3, color='red', marker='o')


ax[1].set_xlabel('BP-RP', fontsize=15)
ax[1].set_ylabel('G mag', fontsize=15)
ax[1].set_ylim(ax[1].set_ylim(6,21)[::-1])
# Out:
# (21, 6)

# %% [markdown]
# # NGC188

# %%
plt.scatter(ngc_pmra,ngc_pmdec, s=0.1)
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.xlabel('$\mu_{a}$ [mas/yr]', fontsize=15)
plt.ylabel('$\mu_{\delta}$ [mas/yr]', fontsize=15)
# Out:
# Text(0,0.5,'$\\mu_{\\delta}$ [mas/yr]')

# %%
ngc_d = 1000/(ngc188["parallax"])

ngc_absgmag = ngc_gmag - 5*np.log10(ngc_d) + 5 + ngc_ext

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,8))
ax[0].scatter(ngc_bprp, ngc_absgmag, s=.9, color='#666666')
ax[0].set_xlabel('BP-RP', fontsize=15)
ax[0].set_ylabel('Abs(G mag)', fontsize=15)
ax[0].set_ylim(ax[0].set_ylim(2,8)[::-1])
ax[0].set_xlim(ax[0].set_xlim(.5,1.75))
ax[0].set_title('NGC188 (1)', size=20)


ichoose3 = np.where((ngc_pmra>-2.9) & (ngc_pmra<-1.1) 
                    & (ngc_pmdec>-2.5) & (ngc_pmdec<0) & (ngc188['parallax'] > 0) & (ngc188['parallax'] < 0.6))

ax[1].scatter(ngc_bprp[ichoose3], ngc_absgmag[ichoose3], s=1, color='red', marker='o')


ax[1].set_xlabel('BP-RP', fontsize=15)
ax[1].set_ylabel('Abs(G mag)', fontsize=15)
ax[1].set_ylim(ax[1].set_ylim(2,8)[::-1])
ax[1].set_xlim(ax[1].set_xlim(.5,1.75))
# Out:
# C:\Users\dougl\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until
# (0.5, 1.75)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,8))
ax[0].scatter(ngc_bprp, ngc_gmag, s=.9, color='#666666')
ax[0].set_xlabel('BP-RP', fontsize=15)
ax[0].set_ylabel('G mag', fontsize=15)
ax[0].set_ylim(ax[0].set_ylim(10,21)[::-1])
ax[0].set_xlim(ax[0].set_xlim(0,3))
ax[0].set_title('NGC188  (2)', size=16)


ichoose3 = np.where((ngc_pmra>-2.9) & (ngc_pmra<-1.1) & (ngc_pmdec>-2.5) & (ngc_pmdec<0) 
                    & (ngc188['parallax'] > 0) & (ngc188['parallax'] < 0.6))

#ax[1].scatter(ngc_bprp, ngc_gmag, s=.4, color='#666666', alpha=0.5)
ax[1].scatter(ngc_bprp[ichoose3], ngc_gmag[ichoose3], s=1, color='red', marker='o')


ax[1].set_xlabel('BP-RP', fontsize=15)
ax[1].set_ylabel('G mag', fontsize=15)
ax[1].set_ylim(ax[1].set_ylim(10,21)[::-1])
ax[1].set_xlim(ax[1].set_xlim(0,3))
# Out:
# (0, 3)

# %% [markdown]
# # Action-Space

# %%
import h5py

catalog = h5py.File("C:/Users/dougl/Downloads/gaia_spectro.hdf5", "r+")
id_sanders = list(catalog['data']['source_id'])
jz = np.array(list(catalog['data']['Jz']))
jr = np.array(list(catalog['data']['JR']))
lz = np.array(list(catalog['data']['Lz']))
l, b = np.array(list(catalog['data']['l'])), np.array(list(catalog['data']['b']))
ra, dec = np.array(list(catalog['data']['ra'])), np.array(list(catalog['data']['dec']))
# Out:
# C:\Users\dougl\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
ichoose_pl = np.where((ra>(np.min(pl_ra))) & (ra<np.max(pl_ra)) & (dec>np.min(pl_dec)) & (dec<np.max(pl_dec)))
ichoose_ngc = np.where((ra>(np.min(ngc_ra))) & (ra<np.max(ngc_ra)) & (dec>np.min(ngc_dec)) & (dec<np.max(ngc_dec)))

# %%
plt.figure(figsize=(10,10))
plt.scatter(jr[ichoose_pl], jz[ichoose_pl], s=28, edgecolor='k', color='blue', alpha=0.1)
plt.xlim(0,20)
plt.ylim(0,10)
plt.xlabel('Jr', size=15)
plt.ylabel('Jz', size=15)
# Out:
# Text(0,0.5,'Jz')

# %% [markdown]
# # Problem 2

# %%
from astropy.io import fits

data_table = fits.open("C:/Users/dougl/Desktop/aspcapStar-r8-l31c.2-2M03343803+7133452.fits")

data = data_table[1].data 
data_err = data_table[2].data

# %%
nwave = data_table[1].header['naxis1'] #Number of wavelengths
crval = data_table[1].header['crval1'] #Start log10(wavelength) 
cdelt = data_table[1].header['cdelt1'] #Dispersion in log10(wavelength) 

print(nwave, crval, cdelt)
# Out:
# 8575 4.179 6e-06

# %%
end = crval + (nwave*cdelt)
grid = np.arange(crval, end, cdelt)
wave_grid = 10**grid

# %%
plt.figure(figsize = (18,10))
plt.plot(wave_grid, data)
plt.xlim(min(wave_grid), max(wave_grid))
plt.ylim(0, max(data)+0.1)
# Out:
# (0, 1.2273699998855592)

# %%
plt.figure(figsize = (18,10))
plt.step(wave_grid, data)
plt.xlim(15522, 15525)
plt.ylim(0.9, 1.1)
# Out:
# (0.9, 1.1)

# %%
abs_idx = np.where([15522 < i < 15525 for i in wave_grid])[0]
abs_flux = data[abs_idx]
abs_flux_err = data_err[abs_idx]
abs_wave_grid = wave_grid[abs_idx]

# %%
cont_region_idx = np.where(abs_flux>1.039)[0]
cont_region = abs_flux[cont_region_idx]

zero_val = np.mean(cont_region)
zero_norm_flux = abs_flux - zero_val
flux_up = abs(zero_norm_flux)

peak_up_idx = np.argmax(flux_up)
peak_up = abs_wave_grid[peak_up_idx]

plt.figure()
plt.step(abs_wave_grid, flux_up)
plt.vlines(peak_up, 0, 0.13)
plt.ylim(0, 0.15)
# Out:
# (0, 0.15)

# %%
def gaussian(x, a, mean, sigma):
    return a * np.exp(-((x - mean)**2 / (2 * sigma**2)))

# %%
from scipy.optimize import curve_fit
peak = max(flux_up)
sigma = np.std(flux_up)

popt, pcov = curve_fit(gaussian, abs_wave_grid, abs_flux, p0=[0.14, peak, sigma])

plt.figure()
plt.plot(abs_wave_grid, gaussian(flux_up, *popt), label='fit')
plt.step(abs_wave_grid, flux_up)
plt.xlim(min(abs_wave_grid), max(abs_wave_grid))
# Out:
# C:\Users\dougl\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# (15522.15443286021, 15524.942487572132)

# %%
def chi_squared(x, model, error):
    chi_sq = (x - model)**2 / error**2
    sum_chi_sq = np.sum(chi_sq) 
    return sum_chi_sq

# %%
popt1, pcov1 = curve_fit(gaussian, abs_wave_grid, abs_flux, p0=[0.18, peak, sigma])
model1 = gaussian(flux_up, *popt1)

popt2, pcov2 = curve_fit(gaussian, abs_wave_grid, abs_flux, p0=[0.14, peak, sigma])
model2 = gaussian(flux_up, *popt2)

popt3, pcov3 = curve_fit(gaussian, abs_wave_grid, abs_flux, p0=[0.10, peak, sigma])
model3 = gaussian(flux_up, *popt3)
# Out:
# C:\Users\dougl\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
fit1 = chi_squared(flux_up, model1, abs_flux_err) 
fit2 = chi_squared(flux_up, model2, abs_flux_err)
fit3 = chi_squared(flux_up, model3, abs_flux_err)

# %%
plt.figure()
plt.plot(abs_wave_grid, model1, color='red')
plt.plot(abs_wave_grid, model2, color='blue')
plt.plot(abs_wave_grid, model3, color='green')
plt.step(abs_wave_grid, flux_up, color='orange')
plt.xlim(min(abs_wave_grid), max(abs_wave_grid))
# Out:
# (15522.15443286021, 15524.942487572132)

# %%
print(fit1, fit2, fit3)
# Out:
# 555.2193 128.06459 86.92472

# %%
popt31, pcov21 = curve_fit(gaussian, abs_wave_grid, abs_flux, p0=[0.10, peak, sigma-0.005])
model31 = gaussian(flux_up, *popt31)

popt32, pcov22 = curve_fit(gaussian, abs_wave_grid, abs_flux, p0=[0.10, peak, sigma])
model32 = gaussian(flux_up, *popt32)

popt33, pcov23 = curve_fit(gaussian, abs_wave_grid, abs_flux, p0=[0.10, peak, sigma+0.005])
model33 = gaussian(flux_up, *popt33)
# Out:
# C:\Users\dougl\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
fit31 = chi_squared(flux_up, model31, abs_flux_err) 
fit32 = chi_squared(flux_up, model32, abs_flux_err)
fit33 = chi_squared(flux_up, model33, abs_flux_err)

# %%
print(fit31, fit32, fit33)
# Out:
# 155.73985 86.92472 40.24736

# %%
plt.figure()
plt.plot(abs_wave_grid, model31, color='red')
plt.plot(abs_wave_grid, model32, color='blue')
plt.plot(abs_wave_grid, model33, color='green')
plt.step(abs_wave_grid, flux_up, color='orange')
plt.xlim(min(abs_wave_grid), max(abs_wave_grid))
# Out:
# (15522.15443286021, 15524.942487572132)

# %%
plt.figure()
plt.plot(abs_wave_grid, model33, color='red')
plt.step(abs_wave_grid, flux_up, color='orange')
plt.xlim(min(abs_wave_grid), max(abs_wave_grid))
# Out:
# (15522.15443286021, 15524.942487572132)

# %%
hdu = fits.open('C:/Users/dougl/Desktop/allStar-l31c.2.fits')

spec_data = hdu[1].data

APOGEE_ID = spec_data["APOGEE_ID"]
T_eff = spec_data['TEFF']
Fe_H = spec_data['FE_H']
logg = spec_data['LOGG']

# %%
onestar_data = fits.open("C:/Users/dougl/Desktop/aspcapStar-r8-l31c.2-2M03343803+7133452.fits")
onestar_flux = onestar_data[1].data

plt.step(wave_grid, onestar_flux)
plt.xlim(15522, 15525)
plt.ylim(0.8, 1.1)
# Out:
# (0.8, 1.1)

# %%
pix_idxs = np.where([15522 < i < 15525 for i in wave_grid])[0]
pixs = onestar_flux[pix_idxs]
wave = wave_grid[pix_idxs]
min_pix_idx = np.argmin(pixs)
min_pix = pixs[min_pix_idx]
pix_wave = wave[min_pix_idx]

# %%
apogee_spec_list = [line.rstrip('\n') for line in open('spectra_list.txt')]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-59-dbda5b783e32> in <module>()
# ----> 1 apogee_spec_list = [line.rstrip('\n') for line in open('spectra_list.txt')]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'spectra_list.txt'
